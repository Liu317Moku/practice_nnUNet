# %%
#改成自己的帳號名稱放置路徑中
# !/opt/conda/condabin/conda env create -f /home/sandy0317/practice_nnUNet/environment.yml
# Out:
# Channels:
#  - pytorch
#  - nvidia
#  - defaults
# Platform: linux-64
# ...
# Solving environment: done
#
# ...
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate nnunet
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
#改成自己的帳號名稱放置路徑中
# !/opt/conda/condabin/conda run -p /home/sandy0317/.conda/envs/nnunet pip install \
    nnunetv2 scikit-image SimpleITK scipy tqdm pandas batchgenerators graphviz matplotlib ipykernel
# Out:
# ...
#   Using cached ipykernel-6.30.1-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached debugpy-1.8.17-cp310-cp310-manylinux_2_34_x86_64.whl.metadata (1.4 kB)
# ...
#   Using cached ipython-8.37.0-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# ...
#   Using cached jupyter_core-5.8.1-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached psutil-7.1.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (23 kB)
# ...
#   Using cached pyzmq-27.1.0-cp310-cp310-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# ...

# %%
#改成自己的帳號名稱放置路徑中
# !/opt/conda/condabin/conda run -p /home/sandy0317/.conda/envs/nnunet python -m ipykernel install --user --name nnunet --display-name "Python (nnU-Net)"
#執行完成後請記得至右上角切換kernel
# Out:
# Installed kernelspec nnunet in /home/sandy0317/.local/share/jupyter/kernels/nnunet

# %%
# !/opt/conda/condabin/conda env list
# Out:
# # conda environments:
# #
# myenv                    /home/sandy0317/.conda/envs/myenv
# nnunet                   /home/sandy0317/.conda/envs/nnunet
# seg                      /home/sandy0317/.conda/envs/seg
# base                     /opt/conda
